# %% [markdown]
# <a href="https://colab.research.google.com/github/benedictpandu/FinalProject_Performances-Analysis/blob/main/Analitika_Bisnis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**NAIVE BAYES**

# %%
import pandas
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score


dataframe = pandas.read_excel("dataset.xlsx")
dataset = dataframe.values
X = dataset[:,0:1000].astype(float)
y = dataset[:,1000]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2
, random_state=0)

from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
clf = model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print('Algoritma: Naive Bayes')
# cm = confusion_matrix(y_test, y_pred)
# print (cm)
acc = accuracy_score(y_test, y_pred)
print('Accuracy Score: ', acc)

print(classification_report(y_test, y_pred))

import matplotlib.pyplot as plt
y_score = model.predict_proba(X_test)
from sklearn.preprocessing import label_binarize

classes = ['A', 'B', 'C', 'D', 'E','F']
y_test = label_binarize(y_test, classes=classes)
n_classes = y_test.shape[1]
from matplotlib import pyplot as plt
from itertools import cycle
from sklearn.metrics import roc_curve, auc
plt.style.use('ggplot')

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
 fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
 roc_auc[i] = auc(fpr[i], tpr[i])
colors = cycle(['gray', 'blue', 'green', 'red', 'yellow'])
for i, color in zip(range(n_classes), colors):
 plt.plot(fpr[i], tpr[i], color=color, lw=1.5, label='ROC curve of class {0} (area = {1:0.2f})' ''.format(classes[i], roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k-', lw=1.5)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Naive Bayes Classifier Algorithm')
plt.legend(loc="lower right")
plt.show()
# Out:
# Algoritma: Naive Bayes
# Accuracy Score:  0.9333333333333333
#               precision    recall  f1-score   support
#
#            A       1.00      1.00      1.00         1
#            B       1.00      1.00      1.00         1
#            C       0.88      1.00      0.93         7
#            D       1.00      1.00      1.00         1
#            E       1.00      0.67      0.80         3
#            F       1.00      1.00      1.00         2
#
#     accuracy                           0.93        15
#    macro avg       0.98      0.94      0.96        15
# weighted avg       0.94      0.93      0.93        15

# %% [markdown]
# # **SVM**

# %%
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from sklearn.multiclass import OneVsRestClassifier
from itertools import cycle
import pandas
plt.style.use('ggplot')


dataframe = pandas.read_excel("dataset.xlsx")
dataset = dataframe.values
X = dataset[:,0:1000:].astype(float)
y = dataset[:,1000]
classes = ['A', 'B', 'C', 'D', 'E','F']
y_bin = label_binarize(y, classes=classes)
n_classes = y_bin.shape[1]
X_train, X_test, y_train, y_test = train_test_split(X, y_bin, test_size
= 0.2, random_state=0)
classifier = OneVsRestClassifier(svm.SVC(kernel='rbf', probability=True
))
y_score = classifier.fit(X_train, y_train).decision_function(X_test)

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
 fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
 roc_auc[i] = auc(fpr[i], tpr[i])
colors = cycle(['blue', 'red', 'green', 'yellow', 'cyan'])
for i, color in zip(range(n_classes), colors):
 plt.plot(fpr[i], tpr[i], color=color, lw=1.5, label='ROC curve of class {0} (area = {1:0.2f})' ''.format(classes[i], roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k-', lw=1.5)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Support Vector Machine Algorithm')
plt.legend(loc="lower right")
print('Algoritma: SVM')


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state=0)
classifier_svc = svm.SVC(kernel='rbf',random_state=0)
classifier_svc.fit(X_train, y_train)
y_pred = classifier_svc.predict(X_test)
from sklearn.metrics import accuracy_score, classification_report

acc = accuracy_score(y_test, y_pred)
print('Accuracy Score: ', acc)
print(classification_report(y_test, y_pred))
plt.show()
# Out:
# Algoritma: SVM
# Accuracy Score:  1.0
#               precision    recall  f1-score   support
#
#            A       1.00      1.00      1.00         1
#            B       1.00      1.00      1.00         1
#            C       1.00      1.00      1.00         7
#            D       1.00      1.00      1.00         1
#            E       1.00      1.00      1.00         3
#            F       1.00      1.00      1.00         2
#
#     accuracy                           1.00        15
#    macro avg       1.00      1.00      1.00        15
# weighted avg       1.00      1.00      1.00        15

# %% [markdown]
# # **RNN**

# %%
# multi-class classification with Keras
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# load dataset
dataframe = pandas.read_excel("dataset.xlsx")
dataset = dataframe.values
ilabel = 1000
jclass = 6
X = dataset[:,0:ilabel].astype(float)
Y = dataset[:,ilabel]

# encode class values as integers
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
# convert integers to dummy variables (i.e. one hot encoded)
dummy_y = np_utils.to_categorical(encoded_Y)

# create model
model = Sequential()
model.add(Dense(8, input_dim=ilabel, activation='relu'))
model.add(Dense(jclass, activation='softmax'))
# Compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

nepochs = 200
nbatch = 5

# ------------ menggunakan packages
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, dummy_y, test_size = 0.20)

model.fit(X_train, y_train, epochs=nepochs, batch_size=nbatch)
_, accuracy = model.evaluate(X_test, y_test)
print('Accuracy Score: %.2f' % (accuracy*100))

model.save_weights("model.h5")
y_score = model.predict(X_test)
y_score
_, accuracy = model.evaluate(X_test, y_test)
print('Accuracy: %.2f' % (accuracy*100) + '%')

import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
classes = ['A', 'B', 'C', 'D', 'E','F']
# Binarize the output
y_test = label_binarize(y_test, classes=classes)
n_classes = y_test.shape[1]
from matplotlib import pyplot as plt
from itertools import cycle
from sklearn.metrics import roc_curve, auc
plt.style.use('ggplot')

# Plotting and estimation of FPR, TPR
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
 fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
 roc_auc[i] = auc(fpr[i], tpr[i])
colors = cycle(['gray', 'blue', 'green', 'red', 'yellow'])
for i, color in zip(range(n_classes), colors):
 plt.plot(fpr[i], tpr[i], color=color, lw=1.5, label='ROC curve of class {0} (area = {1:0.2f})' ''.format(classes[i], roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k-', lw=1.5)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Recurrent Neural Network Deeplearning Algorithm')
plt.legend(loc="lower right")
print('Algoritma:RNN')
plt.show()
# Out:
# Epoch 1/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.7212 - accuracy: 0.3929
# Epoch 2/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6663 - accuracy: 0.7321
# Epoch 3/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3309 - accuracy: 0.9107
# Epoch 4/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1532 - accuracy: 0.9464
# Epoch 5/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1155 - accuracy: 0.9464
# Epoch 6/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1055 - accuracy: 0.9464
# Epoch 7/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0998 - accuracy: 0.9464
# Epoch 8/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0940 - accuracy: 0.9464
# Epoch 9/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0906 - accuracy: 0.9464
# Epoch 10/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0890 - accuracy: 0.9464
# Epoch 11/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0878 - accuracy: 0.9464
# Epoch 12/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0866 - accuracy: 0.9464
# Epoch 13/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0858 - accuracy: 0.9464
# Epoch 14/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0848 - accuracy: 0.9464
# Epoch 15/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0839 - accuracy: 0.9464
# Epoch 16/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0830 - accuracy: 0.9464
# Epoch 17/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0823 - accuracy: 0.9464
# Epoch 18/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0812 - accuracy: 0.9464
# Epoch 19/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0805 - accuracy: 0.9464
# Epoch 20/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0795 - accuracy: 0.9464
# Epoch 21/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0789 - accuracy: 0.9464
# Epoch 22/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0778 - accuracy: 0.9464
# Epoch 23/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0768 - accuracy: 0.9464
# Epoch 24/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0760 - accuracy: 0.9464
# Epoch 25/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0750 - accuracy: 0.9464
# Epoch 26/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0738 - accuracy: 0.9464
# Epoch 27/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0728 - accuracy: 0.9464
# Epoch 28/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0721 - accuracy: 0.9464
# Epoch 29/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0707 - accuracy: 0.9464
# Epoch 30/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0694 - accuracy: 0.9464
# Epoch 31/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0680 - accuracy: 0.9464
# Epoch 32/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0667 - accuracy: 0.9464
# Epoch 33/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0654 - accuracy: 0.9464
# Epoch 34/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0638 - accuracy: 0.9464
# Epoch 35/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0624 - accuracy: 0.9464
# Epoch 36/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0605 - accuracy: 0.9464
# Epoch 37/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0585 - accuracy: 0.9643
# Epoch 38/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0564 - accuracy: 0.9643
# Epoch 39/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0543 - accuracy: 0.9643
# Epoch 40/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0522 - accuracy: 0.9643
# Epoch 41/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0492 - accuracy: 0.9643
# Epoch 42/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0467 - accuracy: 0.9643
# Epoch 43/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0427 - accuracy: 0.9643
# Epoch 44/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 45/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 46/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 47/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 48/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 49/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 50/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 51/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 52/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 53/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 54/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 55/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 56/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 57/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 58/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 59/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 60/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 61/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 62/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 63/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 64/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 65/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 66/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 67/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 68/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 69/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 70/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 71/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 72/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 73/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 74/200
# 12/12 [==============================] - 0s 2ms/step - loss: 9.7634e-04 - accuracy: 1.0000
# Epoch 75/200
# 12/12 [==============================] - 0s 2ms/step - loss: 9.3228e-04 - accuracy: 1.0000
# Epoch 76/200
# 12/12 [==============================] - 0s 2ms/step - loss: 9.0239e-04 - accuracy: 1.0000
# Epoch 77/200
# 12/12 [==============================] - 0s 2ms/step - loss: 8.5946e-04 - accuracy: 1.0000
# Epoch 78/200
# 12/12 [==============================] - 0s 4ms/step - loss: 8.2835e-04 - accuracy: 1.0000
# Epoch 162/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.4385e-04 - accuracy: 1.0000
# Epoch 163/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4202e-04 - accuracy: 1.0000
# Epoch 164/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3993e-04 - accuracy: 1.0000
# Epoch 165/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3832e-04 - accuracy: 1.0000
# Epoch 166/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3622e-04 - accuracy: 1.0000
# Epoch 167/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3464e-04 - accuracy: 1.0000
# Epoch 168/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3290e-04 - accuracy: 1.0000
# Epoch 169/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3129e-04 - accuracy: 1.0000
# Epoch 170/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2940e-04 - accuracy: 1.0000
# Epoch 171/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.2786e-04 - accuracy: 1.0000
# Epoch 172/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2630e-04 - accuracy: 1.0000
# Epoch 173/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2449e-04 - accuracy: 1.0000
# Epoch 174/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.2296e-04 - accuracy: 1.0000
# Epoch 175/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2157e-04 - accuracy: 1.0000
# Epoch 176/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2003e-04 - accuracy: 1.0000
# Epoch 177/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1832e-04 - accuracy: 1.0000
# Epoch 178/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1712e-04 - accuracy: 1.0000
# Epoch 179/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1441e-04 - accuracy: 1.0000
# Epoch 180/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1269e-04 - accuracy: 1.0000
# Epoch 181/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1138e-04 - accuracy: 1.0000
# Epoch 182/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1004e-04 - accuracy: 1.0000
# Epoch 183/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0851e-04 - accuracy: 1.0000
# Epoch 184/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0735e-04 - accuracy: 1.0000
# Epoch 185/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0596e-04 - accuracy: 1.0000
# Epoch 186/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0483e-04 - accuracy: 1.0000
# Epoch 187/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0340e-04 - accuracy: 1.0000
# Epoch 188/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0218e-04 - accuracy: 1.0000
# Epoch 189/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0113e-04 - accuracy: 1.0000
# Epoch 190/200
# 12/12 [==============================] - 0s 2ms/step - loss: 9.9939e-05 - accuracy: 1.0000
# Epoch 191/200
# 12/12 [==============================] - 0s 3ms/step - loss: 9.8773e-05 - accuracy: 1.0000
# Epoch 192/200
# 12/12 [==============================] - 0s 3ms/step - loss: 9.7539e-05 - accuracy: 1.0000
# Epoch 193/200
# 12/12 [==============================] - 0s 2ms/step - loss: 9.6522e-05 - accuracy: 1.0000
# Epoch 194/200
# 12/12 [==============================] - 0s 2ms/step - loss: 9.5045e-05 - accuracy: 1.0000
# Epoch 195/200
# 12/12 [==============================] - 0s 3ms/step - loss: 9.3779e-05 - accuracy: 1.0000
# Epoch 196/200
# 12/12 [==============================] - 0s 3ms/step - loss: 9.2745e-05 - accuracy: 1.0000
# Epoch 197/200
# 12/12 [==============================] - 0s 3ms/step - loss: 9.1869e-05 - accuracy: 1.0000
# Epoch 198/200
# 12/12 [==============================] - 0s 3ms/step - loss: 9.0767e-05 - accuracy: 1.0000
# Epoch 199/200
# 12/12 [==============================] - 0s 6ms/step - loss: 8.9748e-05 - accuracy: 1.0000
# Epoch 200/200
# 12/12 [==============================] - 0s 3ms/step - loss: 8.8699e-05 - accuracy: 1.0000
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7f498db03ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 157ms/step - loss: 0.0237 - accuracy: 1.0000
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f49861df040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Accuracy Score: 100.00
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0237 - accuracy: 1.0000
# Accuracy: 100.00%
# Algoritma:RNN

# %% [markdown]
# # **DECISION TREE**

# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score, classification_report


# load dataset
df= pd.read_excel("dataset.xlsx")
dataset = df.values
X = dataset[:,0:1000:].astype(float)
y = dataset[:,1000]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) 
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print('Algoritma: Decision Tree')
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

import matplotlib.pyplot as plt
y_score = clf.predict_proba(X_test)
from sklearn.preprocessing import label_binarize

classes = ['A', 'B', 'C', 'D', 'E','F']
y_test = label_binarize(y_test, classes=classes)
n_classes = y_test.shape[1]
from matplotlib import pyplot as plt
from itertools import cycle
from sklearn.metrics import roc_curve, auc
plt.style.use('ggplot')

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
 fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
 roc_auc[i] = auc(fpr[i], tpr[i])
colors = cycle(['gray', 'blue', 'green', 'red', 'yellow'])
for i, color in zip(range(n_classes), colors):
 plt.plot(fpr[i], tpr[i], color=color, lw=1.5, label='ROC curve of class {0} (area = {1:0.2f})' ''.format(classes[i], roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k-', lw=1.5)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Decision Tree Algorithm')
plt.legend(loc="lower right")
plt.show()
# Out:
# Algoritma: Decision Tree
# Accuracy: 0.8636363636363636
#               precision    recall  f1-score   support
#
#            A       1.00      1.00      1.00         1
#            C       0.60      0.75      0.67         4
#            D       1.00      1.00      1.00         4
#            E       0.88      0.78      0.82         9
#            F       1.00      1.00      1.00         4
#
#     accuracy                           0.86        22
#    macro avg       0.89      0.91      0.90        22
# weighted avg       0.88      0.86      0.87        22
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_ranking.py:999: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
